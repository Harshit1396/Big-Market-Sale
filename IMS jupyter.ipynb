# %%
import pandas as pd
import numpy as np
% pylab inline  
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
skill = pd.read_csv("B:/Case studies/IMS/A.csv",encoding='cp1252')

# %%
skill
# Out:
#                        Emp Name  Band  Expereince    Old CTC  Max Premium  \
# 0                AAKASH  GOSAIN   4.0        8.07   824685.0         25.0
# 1                  ABDUL  HABIB   3.0       10.72   707963.0         20.0
# 2               ABDUL GAFOOR  A   3.0       17.06   403131.0         45.0
# 3    ABDUL RAHEEM BIN KHALID  .   3.0        6.81   700101.0          0.0
# 4                 ABHAY  TEWARI   4.0       16.03   978623.0         20.0
# 5                  ABHAY  VERMA   4.0       11.25   892520.0         35.0
# 6               ABHIJEET  GUPTA   3.0        3.44   397087.0         35.0
# 7               ABHIJEET  SAHAY   3.0        5.93   578570.0         20.0
# 8         ABHIJIT ASHOK  HARALE   3.0        6.86   819732.0         55.0
# 9        ABHINANDAN  SRIVASTAVA   3.0        6.18   750010.0         20.0
# 10         ABHINAV SINGH  TOMAR   5.0       15.41  1536173.0         40.0
# 11          ABHISEKH  MUKHERJEE   3.0        6.98   515059.0         60.0
# ...

# %%
premium
# Out:
#      S.No.     Practice      Technology  \
# 0        1          IMS  CYBER SECURITY
# 1        2          IMS  CYBER SECURITY
# 2        3          IMS  CYBER SECURITY
# 3        4          IMS  CYBER SECURITY
# 4        5          IMS  CYBER SECURITY
# 5        6          IMS  CYBER SECURITY
# 6        7          IMS  CYBER SECURITY
# 7        8  DIGITAL IMS  CYBER SECURITY
# 8        9  DIGITAL IMS  CYBER SECURITY
# 9       10  DIGITAL IMS  CYBER SECURITY
# 10      11          IMS  CYBER SECURITY
# 11      12          IMS  CYBER SECURITY
# 12      13          IMS  CYBER SECURITY
# 13      14          IMS  CYBER SECURITY
# 14      15          IMS  CYBER SECURITY
# 15      16          IMS  CYBER SECURITY
# 16      17          IMS  CYBER SECURITY
# 17      18          IMS  CYBER SECURITY
# 18      19          IMS  CYBER SECURITY
# 19      20          IMS  CYBER SECURITY
# 20      21          IMS  CYBER SECURITY
# 21      22          IMS  CYBER SECURITY
# ...

# %%
def hist(group):
    group['Diff %'].hist(bins=10)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000243AA663B00>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000243AAD42390>]], dtype=object)

# %%
skill.groupby('Band').apply(hist)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-58016e245be3> in <module>()
# ----> 1 skill.groupby('Band').apply(hist)
#
# C:\Users\Akhand\Anaconda3\lib\site-packages\pandas\core\groupby.py in apply(self, func, *args, **kwargs)
#     719         # ignore SettingWithCopy here in case the user mutates
#     720         with option_context('mode.chained_assignment', None):
# --> 721             return self._python_apply_general(f)
#     722
#     723     def _python_apply_general(self, f):
#
# C:\Users\Akhand\Anaconda3\lib\site-packages\pandas\core\groupby.py in _python_apply_general(self, f)
#     723     def _python_apply_general(self, f):
#     724         keys, values, mutated = self.grouper.apply(f, self._selected_obj,
# --> 725                                                    self.axis)
#     726
#     727         return self._wrap_applied_output(
#
# ...

# %%
m["Skill Premium"].value_counts()
# Out:
# Vanila - 20%       1029
# Niche - 60%          33
# Vanila - 25%         30
# Niche - 50%          22
# Niche - 55% min       6
# Name: Skill Premium, dtype: int64

# %%
m["Skill Premium"].isnull().sum()
# Out:
# 0

# %%
m
# Out:
#                 Skills Cert             Skill Name  S.No.     Practice  \
# 0                Clustering             CLUSTERING    122          IMS
# 1                Clustering             CLUSTERING    123          IMS
# 2                Clustering             CLUSTERING    122          IMS
# 3                Clustering             CLUSTERING    123          IMS
# 4                Clustering             CLUSTERING    122          IMS
# 5                Clustering             CLUSTERING    123          IMS
# 6                Clustering             CLUSTERING    122          IMS
# 7                Clustering             CLUSTERING    123          IMS
# 8                Clustering             CLUSTERING    122          IMS
# 9                Clustering             CLUSTERING    123          IMS
# 10               Clustering             CLUSTERING    122          IMS
# 11               Clustering             CLUSTERING    123          IMS
# ...

# %%
m[m['Skill Name']=='TRENDMICRO']
# Out:
#     Skills Cert  Skill Name  S.No.     Practice      Technology  \
# 720  TrendMicro  TRENDMICRO     10  DIGITAL IMS  CYBER SECURITY
# 721  TrendMicro  TRENDMICRO     19          IMS  CYBER SECURITY
# 722  TrendMicro  TRENDMICRO     10  DIGITAL IMS  CYBER SECURITY
# 723  TrendMicro  TRENDMICRO     19          IMS  CYBER SECURITY
#
#                       Sub Technology       Skill    Skill Premium
# 720  CLOUD & VIRTUALIZATION SECURITY  Trendmicro  Niche - 55% min
# 721      END POINT SECURITY SERVICES  Trendmicro  Niche - 55% min
# 722  CLOUD & VIRTUALIZATION SECURITY  Trendmicro  Niche - 55% min
# 723      END POINT SECURITY SERVICES  Trendmicro  Niche - 55% min

# %%
 skill[skill['Band'] == 1]['Diff % Avg'].hist(bins=3)
 plt.xlabel('Impact Percentage')
 plt.ylabel('Frequency')
 plt.title('Band 1')

# %%
 skill[skill['Band'] == 2]['Diff % Avg'].hist(bins=7)
plt.xlabel('Impact Percentage')
 plt.ylabel('Frequency')
 plt.title('Band 2')

# %%
skill[(skill['Band'] == 3)]['Diff % Avg'].hist(bins=50)
plt.xlabel("Impact Percentage")
plt.ylabel("Frequency")
plt.title('Band 3')

# %%
skill['Diff % Avg'].groupby(skill['Band']).apply(mean)
# Out:
# Band
# 1    23.714286
# 2    34.072464
# 3    95.005525
# 4    60.649123
# 5    33.355140
# 6    -3.708333
# 7   -13.750000
# Name: Diff % Avg, dtype: float64

# %%
skill['Diff % Avg'].groupby(skill['Band']).apply(median)
# Out:
# Band
# 1    21.0
# 2    17.0
# 3    71.5
# 4    48.5
# 5    26.0
# 6    -0.5
# 7   -13.0
# Name: Diff % Avg, dtype: float64

# %%
skill[(skill['Band'] == 4) & (skill['Diff % Avg']<= 300)]['Diff % Avg'].hist(bins=50)
plt.xlabel("Impact Percentage")
plt.ylabel("Frequency")
plt.title('Band 4')

# %%
 skill[skill['Band'] == 5]['Diff % Avg'].hist(bins=5)
 plt.xlabel('Impact Percentage')
 plt.ylabel('Frequency')
 plt.title('Band 5')

# %%
 skill[skill['Band'] == 6]['Diff % Avg'].hist(bins=5)
 plt.xlabel('Impact Percentage')
 plt.ylabel('Frequency')
 plt.title('Band 6')

# %%
 skill[skill['Band'] == 7]['Diff % Avg'].hist(bins=5)
 plt.xlabel('Impact Percentage')
 plt.ylabel('Frequency')
 plt.title('Band 7')

# %%
skill['Band'].unique()
# Out:
# array([4, 3, 5, 2, 6, 1, 7], dtype=int64)

# %%
skill['Band'] = skill['Band'].astype('int')
# Out:
# C:\Users\Akhand\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
skill['Diff % Avg'] = skill['Diff % Avg'].astype('int')
# Out:
# C:\Users\Akhand\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
skill =skill[0:801]

# %%
skill
# Out:
#                        Emp Name  Band  Expereince    Old CTC  Max Premium  \
# 0                AAKASH  GOSAIN     4        8.07   824685.0         25.0
# 1                  ABDUL  HABIB     3       10.72   707963.0         20.0
# 2               ABDUL GAFOOR  A     3       17.06   403131.0         45.0
# 3    ABDUL RAHEEM BIN KHALID  .     3        6.81   700101.0          0.0
# 4                 ABHAY  TEWARI     4       16.03   978623.0         20.0
# 5                  ABHAY  VERMA     4       11.25   892520.0         35.0
# 6               ABHIJEET  GUPTA     3        3.44   397087.0         35.0
# 7               ABHIJEET  SAHAY     3        5.93   578570.0         20.0
# 8         ABHIJIT ASHOK  HARALE     3        6.86   819732.0         55.0
# 9        ABHINANDAN  SRIVASTAVA     3        6.18   750010.0         20.0
# 10         ABHINAV SINGH  TOMAR     5       15.41  1536173.0         40.0
# 11          ABHISEKH  MUKHERJEE     3        6.98   515059.0         60.0
# ...

# %%
skill['Diff % Avg']
# Out:
# 0       41
# 1       99
# 2      465
# 3       16
# 4      106
# 5       77
# 6       12
# 7       35
# 8       16
# 9       18
# 10      49
# 11     105
# 12      66
# 13      49
# 14     -33
# 15      21
# 16      87
# 17       5
# 18      -8
# 19     161
# 20      -2
# 21      22
# 22      -4
# 23      38
# 24      13
# 25     -14
# 26      94
# 27       5
# 28     112
# 29     -17
#       ...
# 771     40
# 772    -16
# 773     72
# 774      8
# 775     39
# 776     40
# 777     18
# 778    188
# 779    -22
# 780     18
# 781     -5
# 782     68
# 783     69
# 784     -7
# 785    127
# 786     63
# 787    112
# 788    167
# 789     -5
# 790    213
# 791    169
# 792     -7
# 793     93
# 794      9
# 795    -22
# 796    213
# 797     17
# 798    244
# 799      7
# 800     29
# Name: Diff % Avg, Length: 801, dtype: int32

# %%
skill[(skill['Band'] == 4) & (skill['Diff % Avg'] <= 200)]

# %%
skill['Diff % Avg'].describe()
# Out:
# count    801.000000
# mean      67.617978
# std       83.666623
# min      -64.000000
# 25%        8.000000
# 50%       42.000000
# 75%      106.000000
# max      535.000000
# Name: Diff % Avg, dtype: float64

# %%
skill[(skill['Band'] == 4) & (skill['Diff % Avg'] >= 25)].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 154 entries, 0 to 793
# Data columns (total 10 columns):
# Emp Name              154 non-null object
# Band                  154 non-null int32
# Expereince            154 non-null float64
# Old CTC               154 non-null float64
# Max Premium           154 non-null float64
# Avg premium           154 non-null float64
# New CTC Avg(Lakhs)    154 non-null float64
# New CTC Max(Lakhs)    154 non-null float64
# Diff % Avg            154 non-null int32
# Diff % Max            154 non-null float64
# dtypes: float64(7), int32(2), object(1)
# memory usage: 12.0+ KB

# %%
skill[(skill['Band'] == 4)].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 228 entries, 0 to 793
# Data columns (total 10 columns):
# Emp Name              228 non-null object
# Band                  228 non-null int32
# Expereince            228 non-null float64
# Old CTC               228 non-null float64
# Max Premium           228 non-null float64
# Avg premium           228 non-null float64
# New CTC Avg(Lakhs)    228 non-null float64
# New CTC Max(Lakhs)    228 non-null float64
# Diff % Avg            228 non-null int32
# Diff % Max            228 non-null float64
# dtypes: float64(7), int32(2), object(1)
# memory usage: 17.8+ KB

# %%
154/228
# Out:
# 0.6754385964912281

# %%
skill.boxplot(column='Diff % Avg', by = 'Band')
plt.ylabel('Impact Percentage')
plt.title('')

# %%
plt.boxplot(skill['Diff % Avg'],1)
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x243afb6de48>],
#  'caps': [<matplotlib.lines.Line2D at 0x243afb7f908>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x243afb86be0>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x243afb86390>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x243afb78828>,
#   <matplotlib.lines.Line2D at 0x243afb78a58>]}

# %%
skill['Est Diff %'] = np.where((skill['Band']==1) & (skill['Diff % Avg']>25),'25',skill['Diff % Avg'])
skill['Est Diff %'] = np.where((skill['Band']==2) & (skill['Diff % Avg']>25),'25',skill['Diff % Avg'])
skill['Est Diff %'] = np.where((skill['Band']==3) & (skill['Diff % Avg']>25),'25',skill['Diff % Avg'])
skill['Est Diff %'] = np.where((skill['Band']==4) & (skill['Diff % Avg']>20),'20',skill['Diff % Avg'])
skill['Est Diff %'] = np.where((skill['Band']==5) & (skill['Diff % Avg']>15),'15',skill['Diff % Avg'])
skill['Est Diff %'] = np.where((skill['Band']==6) & (skill['Diff % Avg']>15),'15',skill['Diff % Avg'])
skill['Est Diff %'] = np.where((skill['Band']==7) & (skill['Diff % Avg']>15),'15',skill['Diff % Avg'])
# Out:
# C:\Users\Akhand\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
skill

# %%
skill[skill['Band']==1]['Est Diff %']=np.where((skill['Diff % Avg']>25),'25',skill['Diff % Avg'])

# %%
average = 25
mock = (skill['Band'] ==1) & (skill['Diff % Avg']>25)
if
